# %% [markdown]
# # FizzBuzz in Python

# %% [markdown]
# In this assignment, the FizzBuzz program demonstrates the division of numbers. Assume the user is given the number 'n,' and they are asked to display the string representations of all the numbers from 1 to n. However, there are some restrictions, such as:
#
# - If the number can be `divided by 3`, it will output Fizz instead of the number.
# - If the number is `divisible by 5`, the result will display Buzz instead of the number.
# - And if the given number is `divisible by both 3 and 5`, Fizz Buzz will be printed instead of the number.
# - If the number `cannot be divided by 3 or 5`, it will be printed as a string.

# %%
# using for loop to iterate between numbers from 1 to 100

for fizzbuzz in range(1,101):
  #checking that number is divisible by both 3 and 5
  if(fizzbuzz%3==0 and fizzbuzz%5==0):
    print("FizzBuzz")
  #checking that number is divisible by 3
  elif(fizzbuzz%3 == 0):
    print("Fizz")
  #checking that number is divisible by 5
  elif(fizzbuzz%5 == 0):
    print("Buzz")
  #And if not divisible by either of them print num as it is
  else:
    print(fizzbuzz)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz
